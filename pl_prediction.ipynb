# %% [raw]
# Use pandas to read in the data we saved in the csv

# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.shape
# Out:
# (5320, 29)

# %% [raw]
# Clean and format our data a bit

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["team_code"] = matches["team"].astype("category").cat.codes

# %%
matches["ref_code"] = matches["referee"].astype("category").cat.codes

# %%
matches["formation_code"] = matches["formation"].str.replace("[^0-9.]", "", regex=True).astype("int")

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["gameweek"] = matches["round"].str.replace("Matchweek ", "").astype("int")

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 38 2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W   1   0
# 39 2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home      D   2   2
# 40 2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W   1   0
# 41 2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home      W   1   0
# 42 2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L   0   2
#
# ...

# %% [raw]
# Set up our random forest classifier model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %% [raw]
# Split training and test sets by date, with ~80% of matches falling into the training set and ~20% in the test set

# %%
train = matches[matches["date"] < '2023-03-01']

# %%
test = matches[matches["date"] >= '2023-03-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code", "gameweek", "team_code", "ref_code", "formation_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %% [raw]
# After fitting the model, our accuracy is alright but our precision seems low

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6343570057581573

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0    1
# actual
# 0           522  110
# 1           271  139

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# np.float64(0.5582329317269076)

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City")

# %% [raw]
# We might be able to attain more accurate predictions by using rolling statistics of recent matches (this is relevant and important data for predicting the next match, as in soccer a team's form tends to come in good and bad streaks)

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(5, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %% [raw]
# We include both actual scoring, shooting, and possession metrics as well as xG (expected goals) metrics which are essentially statistical models of how many goals a team "should have" scored in a match from the chances they created, regardless of how many they actually scored

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt", "xg_x", "xga", "npxg", "poss"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 7  2017-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W   5   0
# 9  2017-09-30  17:30  Premier League   Matchweek 7  Sat  Away      W   1   0
# 10 2017-10-14  15:00  Premier League   Matchweek 8  Sat  Home      W   7   2
# 12 2017-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W   3   0
# 14 2017-10-28  15:00  Premier League  Matchweek 10  Sat  Away      W   3   2
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 51 2024-04-28  16:30  Premier League  Matchweek 35  Sun  Away      W   2   0
# 52 2024-05-04  17:30  Premier League  Matchweek 36  Sat  Home      W   5   1
# 53 2024-05-11  12:30  Premier League  Matchweek 37  Sat  Away      W   4   0
# 54 2024-05-14  20:00  Premier League  Matchweek 34  Tue  Away      W   2   0
# 55 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      W   3   1
#
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# C:\Users\aayan\AppData\Local\Temp\ipykernel_19400\4052147919.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-03-01']
    test = data[data["date"] >= '2023-03-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %% [raw]
# Precision seems to have improved with the addition of these rolling averages

# %%
precision
# Out:
# np.float64(0.6305220883534136)

# %% [raw]
# Our model predicted the result of each match twice, once from the perspective of each team, we can get a better idea of the precision of our model by focusing on situations where its predictions were consistent, i.e. in the match Team X vs Team Y it predicted X would win and Y would lose or vice versa

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Newcastle United": "Newcastle Utd",
    "Tottenham Hotspur": "Tottenham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves",
    "Sheffield United": "Sheffield Utd",
    "Nottingham Forest": "Nott'ham Forest"
}
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    148
# 0     63
# Name: count, dtype: int64

# %% [raw]
# Out of matches X vs Y where our model predicted X would win and Y would lose, it was right 148 times and wrong 63 times, giving us an overall precision of ~70%

# %%
precision = 148 / (148+63)
precision
# Out:
# 0.7014218009478673
